# %% [markdown]
# <a href="https://colab.research.google.com/github/rambabugarlapati/tpm-ai-backlog-agent/blob/main/run_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
# This securely passes your hidden key to the environment so the script can use it
os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')
print("🔑 API Key configured securely!")
# Out:
# 🔑 API Key configured securely!

# %%
# !git clone
# Out:
# fatal: You must specify a repository to clone.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
# ...

# %%
https://github.com
# Out:
#   File "/tmp/ipykernel_3776/2779948116.py", line 1
#     https://github.com
#           ^
# SyntaxError: invalid syntax

# %%
# !git clone https://github.com/rambabugarlapati/tpm-ai-backlog-agent.git
# Out:
# Cloning into 'tpm-ai-backlog-agent'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 68 (delta 21), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (68/68), 24.63 KiB | 4.92 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
https://github.com
# Out:
#   File "/tmp/ipykernel_3776/2779948116.py", line 1
#     https://github.com
#           ^
# SyntaxError: invalid syntax

# %%
# %cd tpm-ai-backlog-agent
# !pip install -r requirements.txt
# !python agent.py
# Out:
# /content/tpm-ai-backlog-agent
# ...
#   File "/content/tpm-ai-backlog-agent/agent.py", line 49
#     Upgrade agent to handle CSV input and output
#             ^^^^^
# SyntaxError: invalid syntax
